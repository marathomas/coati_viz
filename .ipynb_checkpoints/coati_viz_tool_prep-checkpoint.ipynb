# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import matplotlib
import plotly.graph_objs as go
import plotly
import os
import seaborn as sns
from plotly.graph_objs import *
from ipywidgets import Image, HTML, Layout, Output, VBox, HBox
from IPython.display import Audio, display

# %%
import imageio
#import PIL
from PIL import Image, ImageEnhance, ImageFilter
#!pip install librosa==0.7.1
import librosa
import librosa.display
import pylab

# %%
PROJECT_HOME = '/Users/marathomas/Documents/Bioinformatik/Masterarbeit/Unsup_clustering/coati_viz/'
IMAGES_FOLDER = PROJECT_HOME+'spec_images/'
DATA_FOLDER = PROJECT_HOME+'data/'

# %%
os.chdir(PROJECT_HOME)
#df = pd.read_csv('data/viz_data.csv', sep="\t")
df_list=[]

for i in range(1,5):
    check = pd.read_json('data/nfile'+str(i)+'.json', orient ='split', compression = 'infer')
    df_list.append(check)

df = pd.concat(df_list)

# %%
df.head()
# Out:
#      label        start  sr_hz  \
# 0    grunt  2:48:58.745  22050
# 1    grunt  3:18:50.647  22050
# 2  chirpgr     0:00.182  22050
# 3  chirpgr     0:09.480  22050
# 4  barking  2:49:08.268  22050
#
#                                            raw_audio  \
# 0  [-0.00390625, -0.00390625, -0.005859375, -0.00...
# 1  [0.013671875, 0.01171875, 0.0078125, 0.015625,...
# 2  [0.001953125, -0.001953125, -0.0078125, -0.007...
# 3  [0.0, 0.001953125, 0.0078125, 0.005859375, 0.0...
# 4  [-0.001953125, -0.005859375, -0.00390625, -0.0...
#
#                                denoised_spectrograms     UMAP1     UMAP2  \
# 0  [[21.1363868713, 20.6111793518, 23.7496910095,...  3.207488  5.961816
# 1  [[9.191781044, 7.8991680145, 5.7343931198, 2.7...  3.367006  4.102343
# 2  [[14.2165794373, 14.0158252716, 15.7152633667,...  8.085785  2.146757
# 3  [[15.4959335327, 15.7627830505, 15.2638492584,...  8.113145  2.148643
# 4  [[3.6729812622, 5.2803859711, 3.3430747986, -0...  2.572914  3.395229
#
# ...

# %%
IMAGES_FOLDER = 'spec_images/'

# %%
SR = 22050
FFT_WIN = 0.03 # FFT_WIN*samplerate = length of fft/n_fft (number of audio frames that go in one fft)
FFT_HOP = FFT_WIN/8 # FFT_HOP*samplerate = n of audio frames between successive ffts
FMAX = SR/2

def make_img(spec,id):
    outname = str(id)+".jpg"    
    librosa.display.specshow(spec,sr=SR, hop_length=int(FFT_HOP * SR) , fmax=FMAX, y_axis='mel', x_axis='s',cmap='inferno')
    pylab.savefig(outname, bbox_inches=None, pad_inches=0)
    pylab.close()
    #plt.imshow(spec, interpolation='nearest', aspect='equal')
    #plt.savefig(outname)

# %%
#os.chdir(IMAGES_FOLDER)
spec = np.asarray(df.iloc[2,4])
librosa.display.specshow(spec,sr=SR, hop_length=int(FFT_HOP * SR) , fmax=FMAX, y_axis='mel', x_axis='s',cmap='inferno')
pylab.savefig('example.jpg', bbox_inches=None, pad_inches=0)

# %%
#os.chdir(IMAGES_FOLDER)
x = df.apply(lambda row: make_img(np.asarray(row['denoised_spectrograms']),row['index_id']), axis=1)

# %%
pd.Series(df.label).value_counts()
# Out:
# chitter            1125
# chirpgr            1057
# chirpgr n/1        1042
# chirpgr n/2         409
# grunt               176
# chirp               148
# squeal              132
# growl               103
# chittering          102
# chirp n/1            22
# bark grunt           17
# squealing            11
# chirp n/2             9
# squeal chitters       8
# bark                  7
# squeal grunt          6
# grunting              2
# barking               2
# squeal growl          1
# squeal grunts         1
# Name: label, dtype: int64

# %%
# summarize some call types:

call_types = {
    'chirpgr' :["chirpgr n/1","chirpgr n/2", "chirpgr"],
    'chirp' :["chirp","chirp n/1", "chirp n/2"], 
    }

labels_to_calls = dict((v,k) for k in call_types for v in call_types[k])

# %%
lables = [labels_to_calls[label] if label in labels_to_calls.keys() else label for label in df.label]
df['label'] = lables

# %%
pd.Series(df.label).value_counts()
# Out:
# chirpgr            2508
# chitter            1125
# chirp               179
# grunt               176
# squeal              132
# growl               103
# chittering          102
# bark grunt           17
# squealing            11
# squeal chitters       8
# bark                  7
# squeal grunt          6
# grunting              2
# barking               2
# squeal growl          1
# squeal grunts         1
# Name: label, dtype: int64

# %%
df.shape
# Out:
# (4278, 9)

# %%
# Save new df
os.chdir(DATA_FOLDER)
df.iloc[0:1000,:].to_json('nfile1.json', orient = 'split', compression = 'infer', index = 'true') 
df.iloc[1000:2000,:].to_json('nfile2.json', orient = 'split', compression = 'infer', index = 'true') 
df.iloc[2000:3000,:].to_json('nfile3.json', orient = 'split', compression = 'infer', index = 'true') 
df.iloc[3000:,:].to_json('nfile4.json', orient = 'split', compression = 'infer', index = 'true')

# %%
os.chdir(PROJECT_HOME)

image_data = {}
for img_filename in os.listdir(IMAGES_FOLDER):
    img_id = img_filename.split('.')[0]
    with open(IMAGES_FOLDER+img_filename, 'rb') as f:
        b = f.read()
        image_data[img_id] = b

# %%
raw_audio = df.raw_audio.values
samplerate = df.sr_hz.values
df = df.drop(columns=['raw_audio'])

# %%
x, y, z = df['UMAP1'], df['UMAP2'], df['UMAP3']
scat_labels = df['label']

labeltypes = sorted(list(set(scat_labels)))

# makes colors same as AVGN visualization
distinct_colors_14 = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231',
                      '#911eb4', '#46f0f0', '#f032e6', '#fffac8', 
                      '#008080', '#e6beff', '#9a6324', '#000000', '#aaffc3']
customPalette = sns.color_palette(distinct_colors_14, n_colors=len(labeltypes))
color_dict = dict(zip(labeltypes, customPalette))

c = [color_dict[val] for val in scat_labels]

# %%
trace = go.Scatter3d(x=x, y=y, z=z,
                     mode='markers',
                     hovertext = df['label'],
                     marker=dict(size=4,color=c,opacity=0.8))

# %%
data=[trace]

layout = go.Layout(scene=Scene(
                      xaxis=plotly.graph_objs.layout.scene.XAxis(title='UMAP1'),
                      yaxis=plotly.graph_objs.layout.scene.YAxis(title='UMAP2'),
                      zaxis=plotly.graph_objs.layout.scene.ZAxis(title='UMAP3')),
                  height = 700,
                  width = 700)

figure = go.Figure(data=data, layout=layout)

fig = go.FigureWidget(figure)
# Out:
# /Users/marathomas/opt/anaconda3/lib/python3.7/site-packages/plotly/graph_objs/_deprecations.py:494: DeprecationWarning: plotly.graph_objs.Scene is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Scene
#
#   DeprecationWarning,

# %%
scatter = fig.data[0]

scatter.text = df['index_id']
scatter.hoverinfo = 'text'

# %%
details = HTML()

# %%
image_widget = Image(
    value=image_data['20'],
    layout=Layout(height='252px', width='400px')
)

# %%
def play_audio(ind):
    display(Audio(raw_audio[ind], rate=samplerate[ind], autoplay=True))
    
audio_widget = Output()
audio_widget.layout.visibility = 'hidden'


def hover_fn(trace, points, state):

    ind = points.point_inds[0]
    
    # Update details HTML widget
    details.value = df.iloc[ind][['UMAP1', 'UMAP2', 'UMAP3', 'start', 'label', 'index_id']].to_frame().to_html()
    
    # Update image widget
    img_ind = df.iloc[ind]['ind_id']
    image_widget.value = image_data[str(img_ind)]    

scatter.on_hover(hover_fn)

# play sound on click
def click_fn(trace, points, selector):

    ind = points.point_inds[0]
    with audio_widget:
        play_audio(ind)

scatter.on_click(click_fn)

# %%
HBox([
      VBox([details, image_widget, audio_widget]),
    fig])
# Out:
# ...
# /Users/marathomas/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:1152: FutureWarning:
#
#
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4735             try:
# -> 4736                 return libindex.get_value_box(s, key)
#    4737             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# ...
